# %% [markdown]
# # Keras Tuner- Decide Number of Hidden Layers And Neuron In Neural Network

# %%
import pandas as pd
from tensorflow import keras
from keras import layers
from keras.layers import Dense
from kerastuner.tuners import RandomSearch

# %%
dataset = pd.read_csv('Real_Combine.csv')
dataset.head()
# Out:
#       T    TM   Tm     SLP     H   VV    V    VM      PM 2.5
# 0   7.4   9.8  4.8  1017.6  93.0  0.5  4.3   9.4  219.720833
# 1   7.8  12.7  4.4  1018.5  87.0  0.6  4.4  11.1  182.187500
# 2   6.7  13.4  2.4  1019.4  82.0  0.6  4.8  11.1  154.037500
# 3   8.6  15.5  3.3  1018.7  72.0  0.8  8.1  20.6  223.208333
# 4  12.4  20.9  4.4  1017.3  61.0  1.3  8.7  22.2  200.645833

# %%
X = dataset.iloc[:,:-1]
y = dataset.iloc[:,-1]

# %% [markdown]
# # Hyperparameters
# 1.How many number of hidden layers we should have?
#
# 2.How many number of neurons we should have in hidden layers?
#
# 3.Learning Rate

# %%
def build_model(hp):
    model = keras.Sequential()
    for i in range(hp.Int('num_layers', 2, 20)):
        model.add(layers.Dense(units=hp.Int('units_' + str(i),
                                            min_value=32,
                                            max_value=512,
                                            step=32),
                               activation='relu'))
    model.add(layers.Dense(1, activation='linear'))
    model.compile(
        optimizer=keras.optimizers.Adam(
            hp.Choice('learning_rate', [1e-2, 1e-3, 1e-4])),
        loss='mean_absolute_error',
        metrics=['mean_absolute_error'])
    return model

# %%
# val_mean_absolute_error for Regression and val_accuracy for classification
# max trail(5) & executions_per_trial(3). It will do 15(5*3) iteration for each itration in build_model
tuner = RandomSearch(
    build_model,
    objective='val_mean_absolute_error',
    max_trials=5,
    executions_per_trial=3,
    directory='project',
    project_name='Air Quality Index')

# %%
tuner.search_space_summary()
# Out:
# Search space summary
# Default search space size: 4
# num_layers (Int)
# {'default': None, 'conditions': [], 'min_value': 2, 'max_value': 20, 'step': 1, 'sampling': None}
# units_0 (Int)
# {'default': None, 'conditions': [], 'min_value': 32, 'max_value': 512, 'step': 32, 'sampling': None}
# units_1 (Int)
# {'default': None, 'conditions': [], 'min_value': 32, 'max_value': 512, 'step': 32, 'sampling': None}
# learning_rate (Choice)
# {'default': 0.01, 'conditions': [], 'values': [0.01, 0.001, 0.0001], 'ordered': True}

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=0)

# %%
tuner.search(X_train, y_train,
             epochs=5,
             validation_data=(X_test, y_test))
# Out:
# Search: Running Trial #1
#
# Hyperparameter    |Value             |Best Value So Far
# num_layers        |13                |?
# units_0           |256               |?
# units_1           |448               |?
# learning_rate     |0.0001            |?
#
# Epoch 1/5
# 24/24 [==============================] - 2s 19ms/step - loss: nan - mean_absolute_error: nan - val_loss: nan - val_mean_absolute_error: nan
# Epoch 2/5
# 24/24 [==============================] - 0s 10ms/step - loss: nan - mean_absolute_error: nan - val_loss: nan - val_mean_absolute_error: nan
# Epoch 3/5
# 24/24 [==============================] - 0s 8ms/step - loss: nan - mean_absolute_error: nan - val_loss: nan - val_mean_absolute_error: nan
# Epoch 4/5
# 24/24 [==============================] - 0s 13ms/step - loss: nan - mean_absolute_error: nan - val_loss: nan - val_mean_absolute_error: nan
# Epoch 5/5
# ...

# %%
tuner.results_summary()
