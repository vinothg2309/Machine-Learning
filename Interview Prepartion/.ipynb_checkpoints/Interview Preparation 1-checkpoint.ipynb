# %% [markdown]
# # Bayes Theorem
#
# Bayes theorem is also known with some other name such as **Bayes rule or Bayes Law**. Bayes theorem helps to **determine the probability of an event with random knowledge**. It is used to **calculate the probability of occurring one event while other one already occurred**. It is a best method to relate the condition probability and marginal probability.
#
# <img src="attachment:beb79603-79c6-46c3-91da-bacda8b9bb45.png" width=600 />
#
#
# **Calculation:** https://www.mathsisfun.com/data/bayes-theorem.html

# %% [markdown]
# ## Independent event
#
# Tossing 2 coins - Probability is independent of each other.
#
# ## Dependent event
#
# Probability of picking marbles - Black & Red marbles.
#
# **P(A) - 1st Event, P(B|A) - Probability of Event B given Event A(already occurred), P(B) - 2nd Event.**
#
# Here we are considering Event of picking Black marbles.
#
# <img src="attachment:c82cd67d-0f44-4925-b436-7eb50e7edc66.png" width=600 />

# %% [markdown]
# ## Bayes Theorem
#
# <img src="attachment:e3114af3-590c-4978-a3fe-12ac483456cc.png" width=500 />
#
# argmax – max value of Yes/No is considered as prediction.
#
# <img src="attachment:101da3ce-cba1-4986-8c12-e0ee23a5e232.png" width=500 />
#
# Calculate Probability of Yes & No given today & normalize it.
#
# <img src="attachment:474b1b46-e89c-4746-8635-952063ef271d.png" width=500 />
